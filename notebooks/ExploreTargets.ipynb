# %% [markdown]
# # Targets Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from utils import load

# %%
# for task in range(1, 9):
for task in range(1, 3):
    _, target = load(task, 'train')
    
    print(target.dtype)
    
    target.hist()
    plt.show()
# Out:
# float64
# float64

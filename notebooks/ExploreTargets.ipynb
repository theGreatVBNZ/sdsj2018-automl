# %% [markdown]
# # Targets Exploration

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from utils import load

# %% [markdown]
# Create run commands

# %%
folders = [
    'check_1_r', 'check_2_r', 'check_3_r', 'check_4_c', 'check_5_c',
    'check_6_c', 'check_7_c', 'check_8_c',
]

# %%
# for task in range(1, 9):
for task in range(1, 9):
    _, target = load(task, 'train')
    
    print(target.dtype)
    
    target.hist()
    plt.show()
# Out:
# float64
# float64
# float64
# int64
# int64
# float64
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (374) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# float64
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (29,30,369,370,377,378,401,402,445,446,447,448,449,450,452) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# float64
